# %% [markdown]
# ## Day 3：迈入神经网络的“深水区”
#  1.逻辑重构：理解了神经网络本质上就是无数个“逻辑回归”的堆叠。信息通过前向传播预测，误差通过反向传播“甩锅”并修正权重。
#  2. 激活函数的演进： 明白了为什么隐藏层首选ReLU（它在输入大于0时直接输出原值，小于0时输出0）（避免梯度消失，信号传输快），而输出层在多分类时必须用Softmax
#  3. 架构思维：校准了输入与输出的关系--输入由特征决定，输出由分类目标决定。
#  4.对抗过拟合：初步接触了Dropout(随机失活)机制，理解了如何通过“人为制造困难”来让模型变得更强壮（鲁棒性）。
